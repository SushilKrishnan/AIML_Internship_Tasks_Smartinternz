# %% [markdown]
# Assignment - 4 (AI ML)
#
# Name    : Sushil Krishnan
#
# Reg. No.: 21BCE3009
#
# Mail    : sushil.krishnan2021@vitstudent.ac.in
#
# Colab link: https://colab.research.google.com/drive/1i2UDey5A2KCWyaYCkbxw1ZMtsX8vghq0?usp=sharing

# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Loading data

# %%
df = pd.read_csv("/content/winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Dataset Shape

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# #Column information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# #Statistical description

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# #Checking for null values

# %%
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# # Visualization

# %%
#Pairplot
sns.pairplot(df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#Heatmap
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #Outlier replacement

# %%
sns.boxplot(df["fixed acidity"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["fixed acidity"].quantile(0.25)
q3 = df["fixed acidity"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["fixed acidity"].median()
df["fixed acidity"] = np.where(df["fixed acidity"]>upper_limit, median, df["fixed acidity"])
sns.boxplot(df["fixed acidity"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["volatile acidity"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["volatile acidity"].quantile(0.25)
q3 = df["volatile acidity"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["volatile acidity"].median()
df["volatile acidity"] = np.where(df["volatile acidity"]>upper_limit, median, df["volatile acidity"])
sns.boxplot(df["volatile acidity"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["citric acid"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["citric acid"].quantile(0.25)
q3 = df["citric acid"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["citric acid"].median()
df["citric acid"] = np.where(df["citric acid"]>upper_limit, median, df["citric acid"])
sns.boxplot(df["citric acid"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["residual sugar"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["residual sugar"].quantile(0.25)
q3 = df["residual sugar"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["residual sugar"].median()
df["residual sugar"] = np.where(df["residual sugar"]>upper_limit, median, df["residual sugar"])
df["residual sugar"] = np.where(df["residual sugar"]<lower_limit, median, df["residual sugar"])
sns.boxplot(df["residual sugar"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["chlorides"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["chlorides"].quantile(0.25)
q3 = df["chlorides"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["chlorides"].median()
df["chlorides"] = np.where(df["chlorides"]>upper_limit, median, df["chlorides"])
df["chlorides"] = np.where(df["chlorides"]<lower_limit, median, df["chlorides"])
sns.boxplot(df["chlorides"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["free sulfur dioxide"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["free sulfur dioxide"].quantile(0.25)
q3 = df["free sulfur dioxide"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["free sulfur dioxide"].median()
df["free sulfur dioxide"] = np.where(df["free sulfur dioxide"]>upper_limit, median, df["free sulfur dioxide"])
df["free sulfur dioxide"] = np.where(df["free sulfur dioxide"]<lower_limit, median, df["free sulfur dioxide"])
sns.boxplot(df["free sulfur dioxide"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["total sulfur dioxide"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["total sulfur dioxide"].quantile(0.25)
q3 = df["total sulfur dioxide"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["total sulfur dioxide"].median()
df["total sulfur dioxide"] = np.where(df["total sulfur dioxide"]>upper_limit, median, df["total sulfur dioxide"])
df["total sulfur dioxide"] = np.where(df["total sulfur dioxide"]<lower_limit, median, df["total sulfur dioxide"])
sns.boxplot(df["total sulfur dioxide"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["density"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["density"].quantile(0.25)
q3 = df["density"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["density"].median()
df["density"] = np.where(df["density"]>upper_limit, median, df["density"])
df["density"] = np.where(df["density"]<lower_limit, median, df["density"])
sns.boxplot(df["density"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["pH"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["pH"].quantile(0.25)
q3 = df["pH"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["pH"].median()
df["pH"] = np.where(df["pH"]>upper_limit, median, df["pH"])
df["pH"] = np.where(df["pH"]<lower_limit, median, df["pH"])
sns.boxplot(df["pH"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["sulphates"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["sulphates"].quantile(0.25)
q3 = df["sulphates"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["sulphates"].median()
df["sulphates"] = np.where(df["sulphates"]>upper_limit, median, df["sulphates"])
df["sulphates"] = np.where(df["sulphates"]<lower_limit, median, df["sulphates"])
sns.boxplot(df["sulphates"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["alcohol"])
# Out:
# <Axes: >

# %%
#Outlier replacement with median
q1 = df["alcohol"].quantile(0.25)
q3 = df["alcohol"].quantile(0.75)
IQR = q3 - q1
upper_limit = q3+1.5*IQR    #Range after which we have outlier in boxplot
lower_limit = q1-1.5*IQR    #Range below which we have outlier in boxplot
median = df["alcohol"].median()
df["alcohol"] = np.where(df["alcohol"]>upper_limit, median, df["alcohol"])
df["alcohol"] = np.where(df["alcohol"]<lower_limit, median, df["alcohol"])
sns.boxplot(df["alcohol"])
# Out:
# <Axes: >

# %% [markdown]
# #Dependent - Independent variable split

# %%
y = df['quality']
x = df.drop(columns = ['quality'], axis = 1)

# %% [markdown]
# #Scaling

# %%
scale = MinMaxScaler()
xscale = pd.DataFrame(scale.fit_transform(x), columns = x.columns)

# %% [markdown]
# #Train-test split

# %%
x_train,x_test,y_train,y_test = train_test_split(xscale,y,test_size=0.3,random_state=0)

# %% [markdown]
# #Linear regression - regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
modellr = LinearRegression()
modellr.fit(x_train,y_train)
y_pred = modellr.predict(x_test)
print("Test r2 =", metrics.r2_score(y_test,y_pred))
# Out:
# Test r2 = 0.3188575795202093

# %% [markdown]
# # Ridge - regression

# %%
from sklearn.linear_model import Ridge
modelr=Ridge()
modelr.fit(x_train,y_train)
y_pred = modelr.predict(x_test)
print("Test r2 =", metrics.r2_score(y_test,y_pred))
# Out:
# Test r2 = 0.32108211014120336

# %% [markdown]
# # Lasso - regression

# %%
from sklearn.linear_model import Lasso
modell=Lasso()
modell.fit(x_train,y_train)
y_pred = modell.predict(x_test)
print("Test r2 =", metrics.r2_score(y_test,y_pred))
# Out:
# Test r2 = -0.004490893769969029

# %% [markdown]
# # Logistic regression - Classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
modellor = LogisticRegression()
modellor.fit(x_train,y_train)
y_pred = modellor.predict(x_test)
print("Classification accuracy: "+str(accuracy_score(y_test,y_pred)))
# Out:
# Classification accuracy: 0.6125
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Decision tree - Classification

# %%
from sklearn.tree import DecisionTreeClassifier
modeldt = DecisionTreeClassifier()
modeldt.fit(x_train,y_train)
y_pred = modeldt.predict(x_test)
print("Classification accuracy: "+str(accuracy_score(y_test,y_pred)))
# Out:
# Classification accuracy: 0.6208333333333333

# %% [markdown]
# #Random forest classifier - Classification

# %%
from sklearn.ensemble import RandomForestClassifier
modelrf = RandomForestClassifier()
modelrf.fit(x_train,y_train)
y_pred = modelrf.predict(x_test)
print("Classification accuracy: "+str(accuracy_score(y_test,y_pred)))
# Out:
# Classification accuracy: 0.6645833333333333
